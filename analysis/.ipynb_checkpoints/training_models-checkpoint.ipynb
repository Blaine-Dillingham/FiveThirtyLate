# %%
from fastbook import *
setup_book()

import pandas as pd
from pandas.api.types import is_string_dtype, is_numeric_dtype, is_categorical_dtype
from fastai.tabular.all import *
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG

# %%
to = load_pickle('..\\prepared_data\\to.pkl')

# %%
xs, y = to.train.xs, to.train.y
valid_xs, valid_y = to.valid.xs, to.valid.y

# %% [markdown]
# <font size = 6> Decision Trees </font>

# %%
dtree0 = DecisionTreeRegressor(min_samples_leaf=10)
dtree0.fit(xs,y)
draw_tree(dtree0, xs, size=10, leaves_parallel=True, precision=2)

# %%
def r_mse(pred,y): # I will be using root mean square error to evaluate the perform of my model
    return round(math.sqrt(((pred-y)**2).mean()), 6)
def model_rmse(model, xs, y): 
    return r_mse(model.predict(xs), y) 

model_rmse(dtree0, xs, y)
# Out:
# 0.084575

# %%
# error on validation set:
model_rmse(dtree0, valid_xs, valid_y)
# Out:
# 0.115187

# %%
# test various hyperparams
dtrees = []

for num in (5*x for x in range(1, 11)):
    tree = DecisionTreeRegressor(min_samples_leaf=num) # minimum number of data points in a leaf node
    tree.fit(xs,y)
    error = (model_rmse(tree, xs, y), model_rmse(tree, valid_xs, valid_y)) # train and valid errors, respectively
    dtrees.append((tree, error))

dtrees
# Out:
# [(DecisionTreeRegressor(min_samples_leaf=5), (0.069633, 0.113489)),
#  (DecisionTreeRegressor(min_samples_leaf=10), (0.084575, 0.098594)),
#  (DecisionTreeRegressor(min_samples_leaf=15), (0.094155, 0.115911)),
#  (DecisionTreeRegressor(min_samples_leaf=20), (0.106207, 0.108794)),
#  (DecisionTreeRegressor(min_samples_leaf=25), (0.109014, 0.108507)),
#  (DecisionTreeRegressor(min_samples_leaf=30), (0.115178, 0.110678)),
#  (DecisionTreeRegressor(min_samples_leaf=35), (0.119561, 0.122005)),
#  (DecisionTreeRegressor(min_samples_leaf=40), (0.119561, 0.122005)),
#  (DecisionTreeRegressor(min_samples_leaf=45), (0.119561, 0.122005)),
#  (DecisionTreeRegressor(min_samples_leaf=50), (0.119561, 0.122005))]

# %% [markdown]
# The second tree, which had min_samples_leaf = 10, has the lowest validation set error. I now also test various other hyper parameters

# %%
for num in (5*x for x in range(1, 11)):
    tree = DecisionTreeRegressor(min_samples_split=num) # minimum number of samples at which you can split the node
    tree.fit(xs,y)
    error = (model_rmse(tree, xs, y), model_rmse(tree, valid_xs, valid_y)) 
    dtrees.append((tree, error))

for num in range(1, 20):
    tree = DecisionTreeRegressor(max_depth=num) # max depth
    tree.fit(xs,y)
    error = (model_rmse(tree, xs, y), model_rmse(tree, valid_xs, valid_y)) 
    dtrees.append((tree, error))
    
for num in range(4, 80):
    tree = DecisionTreeRegressor(max_leaf_nodes=num) # max number of leaf nodes
    tree.fit(xs,y)
    error = (model_rmse(tree, xs, y), model_rmse(tree, valid_xs, valid_y)) 
    dtrees.append((tree, error))

dtrees
# Out:
# [(DecisionTreeRegressor(min_samples_leaf=5), (0.069633, 0.113489)),
#  (DecisionTreeRegressor(min_samples_leaf=10), (0.084575, 0.098594)),
#  (DecisionTreeRegressor(min_samples_leaf=15), (0.094155, 0.115911)),
#  (DecisionTreeRegressor(min_samples_leaf=20), (0.106207, 0.108794)),
#  (DecisionTreeRegressor(min_samples_leaf=25), (0.109014, 0.108507)),
#  (DecisionTreeRegressor(min_samples_leaf=30), (0.115178, 0.110678)),
#  (DecisionTreeRegressor(min_samples_leaf=35), (0.119561, 0.122005)),
#  (DecisionTreeRegressor(min_samples_leaf=40), (0.119561, 0.122005)),
#  (DecisionTreeRegressor(min_samples_leaf=45), (0.119561, 0.122005)),
#  (DecisionTreeRegressor(min_samples_leaf=50), (0.119561, 0.122005)),
#  (DecisionTreeRegressor(min_samples_split=5), (0.026998, 0.095681)),
#  (DecisionTreeRegressor(min_samples_split=10), (0.055762, 0.115385)),
#  (DecisionTreeRegressor(min_samples_split=15), (0.071154, 0.109353)),
#  (DecisionTreeRegressor(min_samples_split=20), (0.079708, 0.109858)),
#  (DecisionTreeRegressor(min_samples_split=25), (0.080116, 0.087737)),
#  (DecisionTreeRegressor(min_samples_split=30), (0.090039, 0.081894)),
#  (DecisionTreeRegressor(min_samples_split=35), (0.091403, 0.082079)),
#  (DecisionTreeRegressor(min_samples_split=40), (0.092672, 0.086616)),
#  (DecisionTreeRegressor(min_samples_split=45), (0.092672, 0.086616)),
#  (DecisionTreeRegressor(min_samples_split=50), (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=1), (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2), (0.113482, 0.088328)),
#  (DecisionTreeRegressor(max_depth=3), (0.098655, 0.096786)),
#  (DecisionTreeRegressor(max_depth=4), (0.089088, 0.11202)),
#  (DecisionTreeRegressor(max_depth=5), (0.073108, 0.116196)),
#  (DecisionTreeRegressor(max_depth=6), (0.059809, 0.099507)),
#  (DecisionTreeRegressor(max_depth=7), (0.04234, 0.086688)),
#  (DecisionTreeRegressor(max_depth=8), (0.031668, 0.117354)),
#  (DecisionTreeRegressor(max_depth=9), (0.022435, 0.138806)),
#  (DecisionTreeRegressor(max_depth=10), (0.014831, 0.13262)),
#  (DecisionTreeRegressor(max_depth=11), (0.008458, 0.171894)),
#  (DecisionTreeRegressor(max_depth=12), (0.005393, 0.090228)),
#  (DecisionTreeRegressor(max_depth=13), (0.003393, 0.166717)),
#  (DecisionTreeRegressor(max_depth=14), (0.001732, 0.084625)),
#  (DecisionTreeRegressor(max_depth=15), (0.000405, 0.09453)),
#  (DecisionTreeRegressor(max_depth=16), (0.0, 0.085451)),
#  (DecisionTreeRegressor(max_depth=17), (0.0, 0.150638)),
#  (DecisionTreeRegressor(max_depth=18), (0.0, 0.145997)),
#  (DecisionTreeRegressor(max_depth=19), (0.0, 0.143009)),
#  (DecisionTreeRegressor(max_leaf_nodes=4), (0.109965, 0.097919)),
#  (DecisionTreeRegressor(max_leaf_nodes=5), (0.105233, 0.093233)),
#  (DecisionTreeRegressor(max_leaf_nodes=6), (0.099629, 0.098948)),
#  (DecisionTreeRegressor(max_leaf_nodes=7), (0.095036, 0.113085)),
#  (DecisionTreeRegressor(max_leaf_nodes=8), (0.090377, 0.096346)),
#  (DecisionTreeRegressor(max_leaf_nodes=9), (0.086761, 0.099276)),
#  (DecisionTreeRegressor(max_leaf_nodes=10), (0.083665, 0.116948)),
#  (DecisionTreeRegressor(max_leaf_nodes=11), (0.080995, 0.116948)),
#  (DecisionTreeRegressor(max_leaf_nodes=12), (0.078336, 0.097486)),
#  (DecisionTreeRegressor(max_leaf_nodes=13), (0.075858, 0.097486)),
#  (DecisionTreeRegressor(max_leaf_nodes=14), (0.074209, 0.09733)),
#  (DecisionTreeRegressor(max_leaf_nodes=15), (0.072618, 0.093316)),
#  (DecisionTreeRegressor(max_leaf_nodes=16), (0.071005, 0.114528)),
#  (DecisionTreeRegressor(max_leaf_nodes=17), (0.069491, 0.093316)),
#  (DecisionTreeRegressor(max_leaf_nodes=18), (0.067976, 0.115731)),
#  (DecisionTreeRegressor(max_leaf_nodes=19), (0.066457, 0.096293)),
#  (DecisionTreeRegressor(max_leaf_nodes=20), (0.064878, 0.115731)),
#  (DecisionTreeRegressor(max_leaf_nodes=21), (0.063492, 0.115955)),
#  (DecisionTreeRegressor(max_leaf_nodes=22), (0.062181, 0.116075)),
#  (DecisionTreeRegressor(max_leaf_nodes=23), (0.060845, 0.095951)),
#  (DecisionTreeRegressor(max_leaf_nodes=24), (0.059571, 0.115262)),
#  (DecisionTreeRegressor(max_leaf_nodes=25), (0.056793, 0.095535)),
#  (DecisionTreeRegressor(max_leaf_nodes=26), (0.055522, 0.095751)),
#  (DecisionTreeRegressor(max_leaf_nodes=27), (0.054287, 0.135006)),
#  (DecisionTreeRegressor(max_leaf_nodes=28), (0.053038, 0.134923)),
#  (DecisionTreeRegressor(max_leaf_nodes=29), (0.051762, 0.130856)),
#  (DecisionTreeRegressor(max_leaf_nodes=30), (0.050463, 0.137452)),
#  (DecisionTreeRegressor(max_leaf_nodes=31), (0.049275, 0.096527)),
#  (DecisionTreeRegressor(max_leaf_nodes=32), (0.048116, 0.096763)),
#  (DecisionTreeRegressor(max_leaf_nodes=33), (0.046979, 0.092868)),
#  (DecisionTreeRegressor(max_leaf_nodes=34), (0.045895, 0.118146)),
#  (DecisionTreeRegressor(max_leaf_nodes=35), (0.044797, 0.132574)),
#  (DecisionTreeRegressor(max_leaf_nodes=36), (0.043871, 0.092883)),
#  (DecisionTreeRegressor(max_leaf_nodes=37), (0.042932, 0.124933)),
#  (DecisionTreeRegressor(max_leaf_nodes=38), (0.04199, 0.146334)),
#  (DecisionTreeRegressor(max_leaf_nodes=39), (0.041119, 0.153268)),
#  (DecisionTreeRegressor(max_leaf_nodes=40), (0.040241, 0.146721)),
#  (DecisionTreeRegressor(max_leaf_nodes=41), (0.039346, 0.134771)),
#  (DecisionTreeRegressor(max_leaf_nodes=42), (0.038446, 0.093473)),
#  (DecisionTreeRegressor(max_leaf_nodes=43), (0.037546, 0.119074)),
#  (DecisionTreeRegressor(max_leaf_nodes=44), (0.036653, 0.133401)),
#  (DecisionTreeRegressor(max_leaf_nodes=45), (0.035752, 0.149005)),
#  (DecisionTreeRegressor(max_leaf_nodes=46), (0.034934, 0.11863)),
#  (DecisionTreeRegressor(max_leaf_nodes=47), (0.034262, 0.136895)),
#  (DecisionTreeRegressor(max_leaf_nodes=48), (0.033603, 0.117945)),
#  (DecisionTreeRegressor(max_leaf_nodes=49), (0.032933, 0.132395)),
#  (DecisionTreeRegressor(max_leaf_nodes=50), (0.032274, 0.155307)),
#  (DecisionTreeRegressor(max_leaf_nodes=51), (0.03163, 0.123592)),
#  (DecisionTreeRegressor(max_leaf_nodes=52), (0.030685, 0.122701)),
#  (DecisionTreeRegressor(max_leaf_nodes=53), (0.030017, 0.132893)),
#  (DecisionTreeRegressor(max_leaf_nodes=54), (0.029345, 0.144998)),
#  (DecisionTreeRegressor(max_leaf_nodes=55), (0.028684, 0.104789)),
#  (DecisionTreeRegressor(max_leaf_nodes=56), (0.02802, 0.148332)),
#  (DecisionTreeRegressor(max_leaf_nodes=57), (0.02734, 0.132668)),
#  (DecisionTreeRegressor(max_leaf_nodes=58), (0.026738, 0.13668)),
#  (DecisionTreeRegressor(max_leaf_nodes=59), (0.026139, 0.160377)),
#  (DecisionTreeRegressor(max_leaf_nodes=60), (0.025583, 0.121148)),
#  (DecisionTreeRegressor(max_leaf_nodes=61), (0.025032, 0.133985)),
#  (DecisionTreeRegressor(max_leaf_nodes=62), (0.024487, 0.118484)),
#  (DecisionTreeRegressor(max_leaf_nodes=63), (0.023937, 0.149197)),
#  (DecisionTreeRegressor(max_leaf_nodes=64), (0.02338, 0.097164)),
#  (DecisionTreeRegressor(max_leaf_nodes=65), (0.022831, 0.141025)),
#  (DecisionTreeRegressor(max_leaf_nodes=66), (0.022279, 0.119319)),
#  (DecisionTreeRegressor(max_leaf_nodes=67), (0.021782, 0.087922)),
#  (DecisionTreeRegressor(max_leaf_nodes=68), (0.021302, 0.123386)),
#  (DecisionTreeRegressor(max_leaf_nodes=69), (0.020872, 0.171657)),
#  (DecisionTreeRegressor(max_leaf_nodes=70), (0.02044, 0.159435)),
#  (DecisionTreeRegressor(max_leaf_nodes=71), (0.02001, 0.14936)),
#  (DecisionTreeRegressor(max_leaf_nodes=72), (0.019576, 0.127389)),
#  (DecisionTreeRegressor(max_leaf_nodes=73), (0.019201, 0.134988)),
#  (DecisionTreeRegressor(max_leaf_nodes=74), (0.018826, 0.101079)),
#  (DecisionTreeRegressor(max_leaf_nodes=75), (0.01845, 0.134829)),
#  (DecisionTreeRegressor(max_leaf_nodes=76), (0.018067, 0.119858)),
#  (DecisionTreeRegressor(max_leaf_nodes=77), (0.017678, 0.114393)),
#  (DecisionTreeRegressor(max_leaf_nodes=78), (0.017285, 0.087087)),
#  (DecisionTreeRegressor(max_leaf_nodes=79), (0.0169, 0.169728))]

# %%
best = min((tupl[1][1] for tupl in dtrees))
best
# Out:
# 0.081894

# %% [markdown]
# This validation set error would appear to come from the decision tree with min_samples_split=30, so we will choose it as our candidate decision tree for comparison with Random Forest and Neural Net models

# %%
dtree = DecisionTreeRegressor(min_samples_split=30)
dtree.fit(xs, y)
draw_tree(dtree, xs, size=10, leaves_parallel=True, precision=3)

# %%
model_rmse(dtree, valid_xs, valid_y)
# Out:
# 0.081894

# %% [markdown]
# Try nested hyperparameter tuning

# %%
for samples_leaf in (5*x for x in range(1, 11)):
    for samples_split in (5*x for x in range(1, 11)):
        for depth in range(1, 20):
            #for leaf_nodes in range(4, 80):
            tree = DecisionTreeRegressor(min_samples_leaf=samples_leaf, 
                                         min_samples_split=samples_split,
                                         max_depth=depth,
                                         #max_leaf_nodes=leaf_nodes
                                        )
            tree.fit(xs,y)
            error = (model_rmse(tree, xs, y), model_rmse(tree, valid_xs, valid_y)) 
            dtrees.append((tree, error))
                
dtrees
# Out:
# [(DecisionTreeRegressor(min_samples_leaf=5), (0.069633, 0.113489)),
#  (DecisionTreeRegressor(min_samples_leaf=10), (0.084575, 0.098594)),
#  (DecisionTreeRegressor(min_samples_leaf=15), (0.094155, 0.115911)),
#  (DecisionTreeRegressor(min_samples_leaf=20), (0.106207, 0.108794)),
#  (DecisionTreeRegressor(min_samples_leaf=25), (0.109014, 0.108507)),
#  (DecisionTreeRegressor(min_samples_leaf=30), (0.115178, 0.110678)),
#  (DecisionTreeRegressor(min_samples_leaf=35), (0.119561, 0.122005)),
#  (DecisionTreeRegressor(min_samples_leaf=40), (0.119561, 0.122005)),
#  (DecisionTreeRegressor(min_samples_leaf=45), (0.119561, 0.122005)),
#  (DecisionTreeRegressor(min_samples_leaf=50), (0.119561, 0.122005)),
#  (DecisionTreeRegressor(min_samples_split=5), (0.026998, 0.095681)),
#  (DecisionTreeRegressor(min_samples_split=10), (0.055762, 0.115385)),
#  (DecisionTreeRegressor(min_samples_split=15), (0.071154, 0.109353)),
#  (DecisionTreeRegressor(min_samples_split=20), (0.079708, 0.109858)),
#  (DecisionTreeRegressor(min_samples_split=25), (0.080116, 0.087737)),
#  (DecisionTreeRegressor(min_samples_split=30), (0.090039, 0.081894)),
#  (DecisionTreeRegressor(min_samples_split=35), (0.091403, 0.082079)),
#  (DecisionTreeRegressor(min_samples_split=40), (0.092672, 0.086616)),
#  (DecisionTreeRegressor(min_samples_split=45), (0.092672, 0.086616)),
#  (DecisionTreeRegressor(min_samples_split=50), (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=1), (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2), (0.113482, 0.088328)),
#  (DecisionTreeRegressor(max_depth=3), (0.098655, 0.096786)),
#  (DecisionTreeRegressor(max_depth=4), (0.089088, 0.11202)),
#  (DecisionTreeRegressor(max_depth=5), (0.073108, 0.116196)),
#  (DecisionTreeRegressor(max_depth=6), (0.059809, 0.099507)),
#  (DecisionTreeRegressor(max_depth=7), (0.04234, 0.086688)),
#  (DecisionTreeRegressor(max_depth=8), (0.031668, 0.117354)),
#  (DecisionTreeRegressor(max_depth=9), (0.022435, 0.138806)),
#  (DecisionTreeRegressor(max_depth=10), (0.014831, 0.13262)),
#  (DecisionTreeRegressor(max_depth=11), (0.008458, 0.171894)),
#  (DecisionTreeRegressor(max_depth=12), (0.005393, 0.090228)),
#  (DecisionTreeRegressor(max_depth=13), (0.003393, 0.166717)),
#  (DecisionTreeRegressor(max_depth=14), (0.001732, 0.084625)),
#  (DecisionTreeRegressor(max_depth=15), (0.000405, 0.09453)),
#  (DecisionTreeRegressor(max_depth=16), (0.0, 0.085451)),
#  (DecisionTreeRegressor(max_depth=17), (0.0, 0.150638)),
#  (DecisionTreeRegressor(max_depth=18), (0.0, 0.145997)),
#  (DecisionTreeRegressor(max_depth=19), (0.0, 0.143009)),
#  (DecisionTreeRegressor(max_leaf_nodes=4), (0.109965, 0.097919)),
#  (DecisionTreeRegressor(max_leaf_nodes=5), (0.105233, 0.093233)),
#  (DecisionTreeRegressor(max_leaf_nodes=6), (0.099629, 0.098948)),
#  (DecisionTreeRegressor(max_leaf_nodes=7), (0.095036, 0.113085)),
#  (DecisionTreeRegressor(max_leaf_nodes=8), (0.090377, 0.096346)),
#  (DecisionTreeRegressor(max_leaf_nodes=9), (0.086761, 0.099276)),
#  (DecisionTreeRegressor(max_leaf_nodes=10), (0.083665, 0.116948)),
#  (DecisionTreeRegressor(max_leaf_nodes=11), (0.080995, 0.116948)),
#  (DecisionTreeRegressor(max_leaf_nodes=12), (0.078336, 0.097486)),
#  (DecisionTreeRegressor(max_leaf_nodes=13), (0.075858, 0.097486)),
#  (DecisionTreeRegressor(max_leaf_nodes=14), (0.074209, 0.09733)),
#  (DecisionTreeRegressor(max_leaf_nodes=15), (0.072618, 0.093316)),
#  (DecisionTreeRegressor(max_leaf_nodes=16), (0.071005, 0.114528)),
#  (DecisionTreeRegressor(max_leaf_nodes=17), (0.069491, 0.093316)),
#  (DecisionTreeRegressor(max_leaf_nodes=18), (0.067976, 0.115731)),
#  (DecisionTreeRegressor(max_leaf_nodes=19), (0.066457, 0.096293)),
#  (DecisionTreeRegressor(max_leaf_nodes=20), (0.064878, 0.115731)),
#  (DecisionTreeRegressor(max_leaf_nodes=21), (0.063492, 0.115955)),
#  (DecisionTreeRegressor(max_leaf_nodes=22), (0.062181, 0.116075)),
#  (DecisionTreeRegressor(max_leaf_nodes=23), (0.060845, 0.095951)),
#  (DecisionTreeRegressor(max_leaf_nodes=24), (0.059571, 0.115262)),
#  (DecisionTreeRegressor(max_leaf_nodes=25), (0.056793, 0.095535)),
#  (DecisionTreeRegressor(max_leaf_nodes=26), (0.055522, 0.095751)),
#  (DecisionTreeRegressor(max_leaf_nodes=27), (0.054287, 0.135006)),
#  (DecisionTreeRegressor(max_leaf_nodes=28), (0.053038, 0.134923)),
#  (DecisionTreeRegressor(max_leaf_nodes=29), (0.051762, 0.130856)),
#  (DecisionTreeRegressor(max_leaf_nodes=30), (0.050463, 0.137452)),
#  (DecisionTreeRegressor(max_leaf_nodes=31), (0.049275, 0.096527)),
#  (DecisionTreeRegressor(max_leaf_nodes=32), (0.048116, 0.096763)),
#  (DecisionTreeRegressor(max_leaf_nodes=33), (0.046979, 0.092868)),
#  (DecisionTreeRegressor(max_leaf_nodes=34), (0.045895, 0.118146)),
#  (DecisionTreeRegressor(max_leaf_nodes=35), (0.044797, 0.132574)),
#  (DecisionTreeRegressor(max_leaf_nodes=36), (0.043871, 0.092883)),
#  (DecisionTreeRegressor(max_leaf_nodes=37), (0.042932, 0.124933)),
#  (DecisionTreeRegressor(max_leaf_nodes=38), (0.04199, 0.146334)),
#  (DecisionTreeRegressor(max_leaf_nodes=39), (0.041119, 0.153268)),
#  (DecisionTreeRegressor(max_leaf_nodes=40), (0.040241, 0.146721)),
#  (DecisionTreeRegressor(max_leaf_nodes=41), (0.039346, 0.134771)),
#  (DecisionTreeRegressor(max_leaf_nodes=42), (0.038446, 0.093473)),
#  (DecisionTreeRegressor(max_leaf_nodes=43), (0.037546, 0.119074)),
#  (DecisionTreeRegressor(max_leaf_nodes=44), (0.036653, 0.133401)),
#  (DecisionTreeRegressor(max_leaf_nodes=45), (0.035752, 0.149005)),
#  (DecisionTreeRegressor(max_leaf_nodes=46), (0.034934, 0.11863)),
#  (DecisionTreeRegressor(max_leaf_nodes=47), (0.034262, 0.136895)),
#  (DecisionTreeRegressor(max_leaf_nodes=48), (0.033603, 0.117945)),
#  (DecisionTreeRegressor(max_leaf_nodes=49), (0.032933, 0.132395)),
#  (DecisionTreeRegressor(max_leaf_nodes=50), (0.032274, 0.155307)),
#  (DecisionTreeRegressor(max_leaf_nodes=51), (0.03163, 0.123592)),
#  (DecisionTreeRegressor(max_leaf_nodes=52), (0.030685, 0.122701)),
#  (DecisionTreeRegressor(max_leaf_nodes=53), (0.030017, 0.132893)),
#  (DecisionTreeRegressor(max_leaf_nodes=54), (0.029345, 0.144998)),
#  (DecisionTreeRegressor(max_leaf_nodes=55), (0.028684, 0.104789)),
#  (DecisionTreeRegressor(max_leaf_nodes=56), (0.02802, 0.148332)),
#  (DecisionTreeRegressor(max_leaf_nodes=57), (0.02734, 0.132668)),
#  (DecisionTreeRegressor(max_leaf_nodes=58), (0.026738, 0.13668)),
#  (DecisionTreeRegressor(max_leaf_nodes=59), (0.026139, 0.160377)),
#  (DecisionTreeRegressor(max_leaf_nodes=60), (0.025583, 0.121148)),
#  (DecisionTreeRegressor(max_leaf_nodes=61), (0.025032, 0.133985)),
#  (DecisionTreeRegressor(max_leaf_nodes=62), (0.024487, 0.118484)),
#  (DecisionTreeRegressor(max_leaf_nodes=63), (0.023937, 0.149197)),
#  (DecisionTreeRegressor(max_leaf_nodes=64), (0.02338, 0.097164)),
#  (DecisionTreeRegressor(max_leaf_nodes=65), (0.022831, 0.141025)),
#  (DecisionTreeRegressor(max_leaf_nodes=66), (0.022279, 0.119319)),
#  (DecisionTreeRegressor(max_leaf_nodes=67), (0.021782, 0.087922)),
#  (DecisionTreeRegressor(max_leaf_nodes=68), (0.021302, 0.123386)),
#  (DecisionTreeRegressor(max_leaf_nodes=69), (0.020872, 0.171657)),
#  (DecisionTreeRegressor(max_leaf_nodes=70), (0.02044, 0.159435)),
#  (DecisionTreeRegressor(max_leaf_nodes=71), (0.02001, 0.14936)),
#  (DecisionTreeRegressor(max_leaf_nodes=72), (0.019576, 0.127389)),
#  (DecisionTreeRegressor(max_leaf_nodes=73), (0.019201, 0.134988)),
#  (DecisionTreeRegressor(max_leaf_nodes=74), (0.018826, 0.101079)),
#  (DecisionTreeRegressor(max_leaf_nodes=75), (0.01845, 0.134829)),
#  (DecisionTreeRegressor(max_leaf_nodes=76), (0.018067, 0.119858)),
#  (DecisionTreeRegressor(max_leaf_nodes=77), (0.017678, 0.114393)),
#  (DecisionTreeRegressor(max_leaf_nodes=78), (0.017285, 0.087087)),
#  (DecisionTreeRegressor(max_leaf_nodes=79), (0.0169, 0.169728)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=5, min_samples_split=5),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=5, min_samples_split=5),
#   (0.113482, 0.088328)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=5, min_samples_split=5),
#   (0.103471, 0.091528)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=5, min_samples_split=5),
#   (0.09637, 0.085224)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=5, min_samples_split=5),
#   (0.084883, 0.100829)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=5, min_samples_split=5),
#   (0.077117, 0.100779)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=5, min_samples_split=5),
#   (0.072338, 0.098818)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=5, min_samples_split=5),
#   (0.070347, 0.114528)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=5, min_samples_split=5),
#   (0.069882, 0.114364)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=5, min_samples_split=5),
#   (0.069633, 0.113489)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=5, min_samples_split=5),
#   (0.069633, 0.113489)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=5, min_samples_split=5),
#   (0.069633, 0.113489)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=5, min_samples_split=5),
#   (0.069633, 0.097002)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=5, min_samples_split=5),
#   (0.069633, 0.113489)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=5, min_samples_split=5),
#   (0.069633, 0.113489)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=5, min_samples_split=5),
#   (0.069633, 0.097002)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=5, min_samples_split=5),
#   (0.069633, 0.113489)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=5, min_samples_split=5),
#   (0.069633, 0.097002)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=5, min_samples_split=5),
#   (0.069633, 0.113489)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=5, min_samples_split=10),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=5, min_samples_split=10),
#   (0.113482, 0.088328)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=5, min_samples_split=10),
#   (0.103471, 0.091528)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=5, min_samples_split=10),
#   (0.09637, 0.085224)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=5, min_samples_split=10),
#   (0.084883, 0.120727)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=5, min_samples_split=10),
#   (0.077117, 0.118325)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=5, min_samples_split=10),
#   (0.072338, 0.115046)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=5, min_samples_split=10),
#   (0.070347, 0.114528)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=5, min_samples_split=10),
#   (0.069882, 0.114364)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=5, min_samples_split=10),
#   (0.069633, 0.113489)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=5, min_samples_split=10),
#   (0.069633, 0.113489)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=5, min_samples_split=10),
#   (0.069633, 0.113489)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=5, min_samples_split=10),
#   (0.069633, 0.113489)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=5, min_samples_split=10),
#   (0.069633, 0.097002)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=5, min_samples_split=10),
#   (0.069633, 0.097002)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=5, min_samples_split=10),
#   (0.069633, 0.097002)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=5, min_samples_split=10),
#   (0.069633, 0.097002)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=5, min_samples_split=10),
#   (0.069633, 0.097002)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=5, min_samples_split=10),
#   (0.069633, 0.097002)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=5, min_samples_split=15),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=5, min_samples_split=15),
#   (0.113482, 0.088328)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=5, min_samples_split=15),
#   (0.1038, 0.091719)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=5, min_samples_split=15),
#   (0.096723, 0.085429)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=5, min_samples_split=15),
#   (0.086652, 0.115144)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=5, min_samples_split=15),
#   (0.079606, 0.093948)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=5, min_samples_split=15),
#   (0.076188, 0.109111)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=5, min_samples_split=15),
#   (0.075524, 0.108619)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=5, min_samples_split=15),
#   (0.075091, 0.108446)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=5, min_samples_split=15),
#   (0.074859, 0.087845)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=5, min_samples_split=15),
#   (0.074859, 0.087845)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=5, min_samples_split=15),
#   (0.074859, 0.087845)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=5, min_samples_split=15),
#   (0.074859, 0.087845)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=5, min_samples_split=15),
#   (0.074859, 0.087845)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=5, min_samples_split=15),
#   (0.074859, 0.087845)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=5, min_samples_split=15),
#   (0.074859, 0.107522)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=5, min_samples_split=15),
#   (0.074859, 0.107522)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=5, min_samples_split=15),
#   (0.074859, 0.107522)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=5, min_samples_split=15),
#   (0.074859, 0.107522)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=5, min_samples_split=20),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=5, min_samples_split=20),
#   (0.113482, 0.088328)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=5, min_samples_split=20),
#   (0.1038, 0.091719)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=5, min_samples_split=20),
#   (0.097513, 0.086524)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=5, min_samples_split=20),
#   (0.087864, 0.095696)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=5, min_samples_split=20),
#   (0.082176, 0.092575)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=5, min_samples_split=20),
#   (0.080742, 0.110515)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=5, min_samples_split=20),
#   (0.080116, 0.110029)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=5, min_samples_split=20),
#   (0.079708, 0.087522)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=5, min_samples_split=20),
#   (0.079708, 0.087522)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=5, min_samples_split=20),
#   (0.079708, 0.087522)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=5, min_samples_split=20),
#   (0.079708, 0.109858)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=5, min_samples_split=20),
#   (0.079708, 0.087522)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=5, min_samples_split=20),
#   (0.079708, 0.109858)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=5, min_samples_split=20),
#   (0.079708, 0.087522)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=5, min_samples_split=20),
#   (0.079708, 0.087522)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=5, min_samples_split=20),
#   (0.079708, 0.109858)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=5, min_samples_split=20),
#   (0.079708, 0.109858)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=5, min_samples_split=20),
#   (0.079708, 0.087522)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=5, min_samples_split=25),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=5, min_samples_split=25),
#   (0.113482, 0.088328)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=5, min_samples_split=25),
#   (0.1038, 0.091719)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=5, min_samples_split=25),
#   (0.097513, 0.086524)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=5, min_samples_split=25),
#   (0.087864, 0.116475)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=5, min_samples_split=25),
#   (0.082176, 0.113925)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=5, min_samples_split=25),
#   (0.080742, 0.088345)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=5, min_samples_split=25),
#   (0.080116, 0.110029)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=5, min_samples_split=25),
#   (0.080116, 0.087737)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=5, min_samples_split=25),
#   (0.080116, 0.110029)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=5, min_samples_split=25),
#   (0.080116, 0.110029)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=5, min_samples_split=25),
#   (0.080116, 0.087737)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=5, min_samples_split=25),
#   (0.080116, 0.110029)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=5, min_samples_split=25),
#   (0.080116, 0.110029)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=5, min_samples_split=25),
#   (0.080116, 0.087737)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=5, min_samples_split=25),
#   (0.080116, 0.087737)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=5, min_samples_split=25),
#   (0.080116, 0.110029)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=5, min_samples_split=25),
#   (0.080116, 0.087737)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=5, min_samples_split=25),
#   (0.080116, 0.110029)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=5, min_samples_split=30),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=5, min_samples_split=30),
#   (0.113482, 0.088328)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=5, min_samples_split=30),
#   (0.1038, 0.091719)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=5, min_samples_split=30),
#   (0.097513, 0.086524)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=5, min_samples_split=30),
#   (0.094171, 0.089775)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=5, min_samples_split=30),
#   (0.091327, 0.086441)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=5, min_samples_split=30),
#   (0.090039, 0.081894)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=5, min_samples_split=30),
#   (0.090039, 0.081894)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=5, min_samples_split=30),
#   (0.090039, 0.081894)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=5, min_samples_split=30),
#   (0.090039, 0.081894)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=5, min_samples_split=30),
#   (0.090039, 0.081894)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=5, min_samples_split=30),
#   (0.090039, 0.081894)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=5, min_samples_split=30),
#   (0.090039, 0.081894)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=5, min_samples_split=30),
#   (0.090039, 0.081894)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=5, min_samples_split=30),
#   (0.090039, 0.081894)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=5, min_samples_split=30),
#   (0.090039, 0.081894)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=5, min_samples_split=30),
#   (0.090039, 0.081894)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=5, min_samples_split=30),
#   (0.090039, 0.081894)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=5, min_samples_split=30),
#   (0.090039, 0.081894)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=5, min_samples_split=35),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=5, min_samples_split=35),
#   (0.113482, 0.088328)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=5, min_samples_split=35),
#   (0.1038, 0.091719)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=5, min_samples_split=35),
#   (0.098773, 0.086699)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=5, min_samples_split=35),
#   (0.095476, 0.089944)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=5, min_samples_split=35),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=5, min_samples_split=35),
#   (0.091403, 0.082079)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=5, min_samples_split=35),
#   (0.091403, 0.082079)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=5, min_samples_split=35),
#   (0.091403, 0.082079)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=5, min_samples_split=35),
#   (0.091403, 0.082079)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=5, min_samples_split=35),
#   (0.091403, 0.082079)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=5, min_samples_split=35),
#   (0.091403, 0.082079)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=5, min_samples_split=35),
#   (0.091403, 0.082079)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=5, min_samples_split=35),
#   (0.091403, 0.082079)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=5, min_samples_split=35),
#   (0.091403, 0.082079)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=5, min_samples_split=35),
#   (0.091403, 0.082079)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=5, min_samples_split=35),
#   (0.091403, 0.082079)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=5, min_samples_split=35),
#   (0.091403, 0.082079)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=5, min_samples_split=35),
#   (0.091403, 0.082079)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=5, min_samples_split=40),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=5, min_samples_split=40),
#   (0.113482, 0.088328)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=5, min_samples_split=40),
#   (0.1038, 0.091719)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=5, min_samples_split=40),
#   (0.098773, 0.086699)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=5, min_samples_split=40),
#   (0.095476, 0.089944)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=5, min_samples_split=40),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=5, min_samples_split=40),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=5, min_samples_split=40),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=5, min_samples_split=40),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=5, min_samples_split=40),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=5, min_samples_split=40),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=5, min_samples_split=40),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=5, min_samples_split=40),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=5, min_samples_split=40),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=5, min_samples_split=40),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=5, min_samples_split=40),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=5, min_samples_split=40),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=5, min_samples_split=40),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=5, min_samples_split=40),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=5, min_samples_split=45),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=5, min_samples_split=45),
#   (0.113482, 0.088328)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=5, min_samples_split=45),
#   (0.1038, 0.091719)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=5, min_samples_split=45),
#   (0.098773, 0.086699)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=5, min_samples_split=45),
#   (0.095476, 0.089944)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=5, min_samples_split=45),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=5, min_samples_split=45),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=5, min_samples_split=45),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=5, min_samples_split=45),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=5, min_samples_split=45),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=5, min_samples_split=45),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=5, min_samples_split=45),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=5, min_samples_split=45),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=5, min_samples_split=45),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=5, min_samples_split=45),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=5, min_samples_split=45),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=5, min_samples_split=45),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=5, min_samples_split=45),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=5, min_samples_split=45),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=5, min_samples_split=50),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=5, min_samples_split=50),
#   (0.113482, 0.088328)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=5, min_samples_split=50),
#   (0.1038, 0.091719)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=5, min_samples_split=50),
#   (0.098773, 0.086699)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=5, min_samples_split=50),
#   (0.095476, 0.089944)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=5, min_samples_split=50),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=5, min_samples_split=50),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=5, min_samples_split=50),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=5, min_samples_split=50),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=5, min_samples_split=50),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=5, min_samples_split=50),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=5, min_samples_split=50),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=5, min_samples_split=50),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=5, min_samples_split=50),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=5, min_samples_split=50),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=5, min_samples_split=50),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=5, min_samples_split=50),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=5, min_samples_split=50),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=5, min_samples_split=50),
#   (0.092672, 0.086616)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=10, min_samples_split=5),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=10, min_samples_split=5),
#   (0.113795, 0.096511)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=10, min_samples_split=5),
#   (0.102611, 0.10876)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=10, min_samples_split=5),
#   (0.096967, 0.103317)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=10, min_samples_split=5),
#   (0.093397, 0.100792)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=10, min_samples_split=5),
#   (0.089221, 0.100589)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=10, min_samples_split=5),
#   (0.087079, 0.115187)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=10, min_samples_split=5),
#   (0.085457, 0.101033)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=10, min_samples_split=5),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=10, min_samples_split=5),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=10, min_samples_split=5),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=10, min_samples_split=5),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=10, min_samples_split=5),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=10, min_samples_split=5),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=10, min_samples_split=5),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=10, min_samples_split=5),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=10, min_samples_split=5),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=10, min_samples_split=5),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=10, min_samples_split=5),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=10, min_samples_split=10),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=10, min_samples_split=10),
#   (0.113795, 0.096511)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=10, min_samples_split=10),
#   (0.102611, 0.10876)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=10, min_samples_split=10),
#   (0.096967, 0.103317)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=10, min_samples_split=10),
#   (0.093397, 0.100792)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=10, min_samples_split=10),
#   (0.089221, 0.100589)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=10, min_samples_split=10),
#   (0.087079, 0.115187)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=10, min_samples_split=10),
#   (0.085457, 0.115187)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=10, min_samples_split=10),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=10, min_samples_split=10),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=10, min_samples_split=10),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=10, min_samples_split=10),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=10, min_samples_split=10),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=10, min_samples_split=10),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=10, min_samples_split=10),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=10, min_samples_split=10),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=10, min_samples_split=10),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=10, min_samples_split=10),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=10, min_samples_split=10),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=10, min_samples_split=15),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=10, min_samples_split=15),
#   (0.113795, 0.096511)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=10, min_samples_split=15),
#   (0.102611, 0.10876)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=10, min_samples_split=15),
#   (0.096967, 0.103317)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=10, min_samples_split=15),
#   (0.093397, 0.100792)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=10, min_samples_split=15),
#   (0.089221, 0.100589)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=10, min_samples_split=15),
#   (0.087079, 0.099197)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=10, min_samples_split=15),
#   (0.085457, 0.115187)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=10, min_samples_split=15),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=10, min_samples_split=15),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=10, min_samples_split=15),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=10, min_samples_split=15),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=10, min_samples_split=15),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=10, min_samples_split=15),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=10, min_samples_split=15),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=10, min_samples_split=15),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=10, min_samples_split=15),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=10, min_samples_split=15),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=10, min_samples_split=15),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=10, min_samples_split=20),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=10, min_samples_split=20),
#   (0.113795, 0.096511)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=10, min_samples_split=20),
#   (0.102611, 0.10876)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=10, min_samples_split=20),
#   (0.096967, 0.103317)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=10, min_samples_split=20),
#   (0.093397, 0.100792)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=10, min_samples_split=20),
#   (0.089221, 0.100589)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=10, min_samples_split=20),
#   (0.087079, 0.115187)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=10, min_samples_split=20),
#   (0.085457, 0.115187)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=10, min_samples_split=20),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=10, min_samples_split=20),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=10, min_samples_split=20),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=10, min_samples_split=20),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=10, min_samples_split=20),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=10, min_samples_split=20),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=10, min_samples_split=20),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=10, min_samples_split=20),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=10, min_samples_split=20),
#   (0.084575, 0.115187)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=10, min_samples_split=20),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=10, min_samples_split=20),
#   (0.084575, 0.098594)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=10, min_samples_split=25),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=10, min_samples_split=25),
#   (0.113795, 0.096511)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=10, min_samples_split=25),
#   (0.104624, 0.102106)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=10, min_samples_split=25),
#   (0.099095, 0.096288)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=10, min_samples_split=25),
#   (0.095604, 0.093573)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=10, min_samples_split=25),
#   (0.091788, 0.093355)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=10, min_samples_split=25),
#   (0.089708, 0.108927)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=10, min_samples_split=25),
#   (0.088134, 0.093833)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=10, min_samples_split=25),
#   (0.087279, 0.108927)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=10, min_samples_split=25),
#   (0.087279, 0.108927)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=10, min_samples_split=25),
#   (0.087279, 0.091201)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=10, min_samples_split=25),
#   (0.087279, 0.091201)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=10, min_samples_split=25),
#   (0.087279, 0.091201)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=10, min_samples_split=25),
#   (0.087279, 0.091201)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=10, min_samples_split=25),
#   (0.087279, 0.091201)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=10, min_samples_split=25),
#   (0.087279, 0.091201)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=10, min_samples_split=25),
#   (0.087279, 0.108927)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=10, min_samples_split=25),
#   (0.087279, 0.108927)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=10, min_samples_split=25),
#   (0.087279, 0.091201)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=10, min_samples_split=30),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=10, min_samples_split=30),
#   (0.113795, 0.096511)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=10, min_samples_split=30),
#   (0.104624, 0.102106)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=10, min_samples_split=30),
#   (0.099608, 0.096927)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=10, min_samples_split=30),
#   (0.096136, 0.09423)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=10, min_samples_split=30),
#   (0.092342, 0.094013)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=10, min_samples_split=30),
#   (0.090275, 0.092522)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=10, min_samples_split=30),
#   (0.088711, 0.109492)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=10, min_samples_split=30),
#   (0.087862, 0.091875)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=10, min_samples_split=30),
#   (0.087862, 0.091875)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=10, min_samples_split=30),
#   (0.087862, 0.091875)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=10, min_samples_split=30),
#   (0.087862, 0.091875)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=10, min_samples_split=30),
#   (0.087862, 0.109492)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=10, min_samples_split=30),
#   (0.087862, 0.109492)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=10, min_samples_split=30),
#   (0.087862, 0.109492)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=10, min_samples_split=30),
#   (0.087862, 0.091875)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=10, min_samples_split=30),
#   (0.087862, 0.091875)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=10, min_samples_split=30),
#   (0.087862, 0.109492)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=10, min_samples_split=30),
#   (0.087862, 0.091875)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=10, min_samples_split=35),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=10, min_samples_split=35),
#   (0.113795, 0.096511)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=10, min_samples_split=35),
#   (0.104624, 0.102106)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=10, min_samples_split=35),
#   (0.099608, 0.096927)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=10, min_samples_split=35),
#   (0.096136, 0.09423)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=10, min_samples_split=35),
#   (0.092342, 0.094013)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=10, min_samples_split=35),
#   (0.090275, 0.092522)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=10, min_samples_split=35),
#   (0.088711, 0.109492)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=10, min_samples_split=35),
#   (0.088711, 0.109492)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=10, min_samples_split=35),
#   (0.088711, 0.094488)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=10, min_samples_split=35),
#   (0.088711, 0.109492)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=10, min_samples_split=35),
#   (0.088711, 0.094488)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=10, min_samples_split=35),
#   (0.088711, 0.109492)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=10, min_samples_split=35),
#   (0.088711, 0.109492)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=10, min_samples_split=35),
#   (0.088711, 0.094488)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=10, min_samples_split=35),
#   (0.088711, 0.094488)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=10, min_samples_split=35),
#   (0.088711, 0.109492)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=10, min_samples_split=35),
#   (0.088711, 0.094488)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=10, min_samples_split=35),
#   (0.088711, 0.094488)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=10, min_samples_split=40),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=10, min_samples_split=40),
#   (0.113795, 0.096511)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=10, min_samples_split=40),
#   (0.106382, 0.097999)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=10, min_samples_split=40),
#   (0.101453, 0.09259)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=10, min_samples_split=40),
#   (0.098046, 0.089763)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=10, min_samples_split=40),
#   (0.09433, 0.089536)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=10, min_samples_split=40),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=10, min_samples_split=40),
#   (0.090778, 0.090035)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=10, min_samples_split=40),
#   (0.090778, 0.090035)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=10, min_samples_split=40),
#   (0.090778, 0.090035)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=10, min_samples_split=40),
#   (0.090778, 0.090035)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=10, min_samples_split=40),
#   (0.090778, 0.105672)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=10, min_samples_split=40),
#   (0.090778, 0.090035)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=10, min_samples_split=40),
#   (0.090778, 0.105672)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=10, min_samples_split=40),
#   (0.090778, 0.090035)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=10, min_samples_split=40),
#   (0.090778, 0.090035)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=10, min_samples_split=40),
#   (0.090778, 0.105672)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=10, min_samples_split=40),
#   (0.090778, 0.105672)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=10, min_samples_split=40),
#   (0.090778, 0.090035)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=10, min_samples_split=45),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=10, min_samples_split=45),
#   (0.113795, 0.096511)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=10, min_samples_split=45),
#   (0.106382, 0.097999)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=10, min_samples_split=45),
#   (0.101453, 0.09259)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=10, min_samples_split=45),
#   (0.098046, 0.089763)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=10, min_samples_split=45),
#   (0.09433, 0.089536)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=10, min_samples_split=45),
#   (0.092307, 0.105672)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=10, min_samples_split=45),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=10, min_samples_split=45),
#   (0.092307, 0.105672)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=10, min_samples_split=45),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=10, min_samples_split=45),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=10, min_samples_split=45),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=10, min_samples_split=45),
#   (0.092307, 0.105672)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=10, min_samples_split=45),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=10, min_samples_split=45),
#   (0.092307, 0.105672)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=10, min_samples_split=45),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=10, min_samples_split=45),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=10, min_samples_split=45),
#   (0.092307, 0.105672)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=10, min_samples_split=45),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=10, min_samples_split=50),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=10, min_samples_split=50),
#   (0.113795, 0.096511)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=10, min_samples_split=50),
#   (0.106382, 0.097999)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=10, min_samples_split=50),
#   (0.101453, 0.09259)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=10, min_samples_split=50),
#   (0.098046, 0.089763)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=10, min_samples_split=50),
#   (0.09433, 0.089536)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=10, min_samples_split=50),
#   (0.092307, 0.105672)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=10, min_samples_split=50),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=10, min_samples_split=50),
#   (0.092307, 0.105672)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=10, min_samples_split=50),
#   (0.092307, 0.105672)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=10, min_samples_split=50),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=10, min_samples_split=50),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=10, min_samples_split=50),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=10, min_samples_split=50),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=10, min_samples_split=50),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=10, min_samples_split=50),
#   (0.092307, 0.105672)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=10, min_samples_split=50),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=10, min_samples_split=50),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=10, min_samples_split=50),
#   (0.092307, 0.087969)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=15, min_samples_split=5),
#   (0.126005, 0.110935)),
# ...
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=20, min_samples_split=45),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=20, min_samples_split=45),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=20, min_samples_split=45),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=20, min_samples_split=45),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=20, min_samples_split=45),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=20, min_samples_split=45),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=20, min_samples_split=50),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=20, min_samples_split=50),
#   (0.116069, 0.12242)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=20, min_samples_split=50),
#   (0.106207, 0.108794)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=25, min_samples_split=5),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=25, min_samples_split=5),
#   (0.116701, 0.122137)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=25, min_samples_split=5),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=25, min_samples_split=10),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=25, min_samples_split=10),
#   (0.116701, 0.122137)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=25, min_samples_split=10),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=25, min_samples_split=15),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=25, min_samples_split=15),
#   (0.116701, 0.122137)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=25, min_samples_split=15),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=25, min_samples_split=20),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=25, min_samples_split=20),
#   (0.116701, 0.122137)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=25, min_samples_split=20),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=25, min_samples_split=25),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=25, min_samples_split=25),
#   (0.116701, 0.122137)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=25, min_samples_split=25),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=25, min_samples_split=30),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=25, min_samples_split=30),
#   (0.116701, 0.122137)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=12, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=13, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=14, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=15, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=16, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=17, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=18, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=19, min_samples_leaf=25, min_samples_split=30),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=1, min_samples_leaf=25, min_samples_split=35),
#   (0.126005, 0.110935)),
#  (DecisionTreeRegressor(max_depth=2, min_samples_leaf=25, min_samples_split=35),
#   (0.116701, 0.122137)),
#  (DecisionTreeRegressor(max_depth=3, min_samples_leaf=25, min_samples_split=35),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=4, min_samples_leaf=25, min_samples_split=35),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=5, min_samples_leaf=25, min_samples_split=35),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=6, min_samples_leaf=25, min_samples_split=35),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=7, min_samples_leaf=25, min_samples_split=35),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=8, min_samples_leaf=25, min_samples_split=35),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=9, min_samples_leaf=25, min_samples_split=35),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=10, min_samples_leaf=25, min_samples_split=35),
#   (0.109014, 0.108507)),
#  (DecisionTreeRegressor(max_depth=11, min_samples_leaf=25, min_samples_split=35),
#   (0.109014, 0.108507)),
#  ...]

# %%
best = min((tupl[1][1] for tupl in dtrees))
best
# Out:
# 0.081894

# %% [markdown]
# So trying all the combinations of these hyperparameters didn't yield anything better than trying the hyperparameters separately

# %%
save_pickle('trained_models\\dtree_best.pkl',dtree)

# %% [markdown]
# <font size = 6> Random Forests</font>

# %%
def rf(xs, y, n_estimators=40, max_samples=184, # size of my training set
       max_features=0.5, min_samples_leaf=5, **kwargs):
    return RandomForestRegressor(n_jobs=-1, # means to use all available processors in parallel
                                 n_estimators=n_estimators,
        max_samples=max_samples, max_features=max_features,
        min_samples_leaf=min_samples_leaf, oob_score=True).fit(xs, y)

# %%
rf0 = rf(xs, y, max_samples=184)

# %%
model_rmse(rf0, xs, y), model_rmse(rf0, valid_xs, valid_y)
# Out:
# (0.076103, 0.087086)

# %% [markdown]
# My first random forest, with no hyperparameter tuning, is comparable to the very best decision tree
#
# The best random forest I've been able to generate so far, and which has been difficult to replicate due to the stochasticity of random forest training, is the one below.

# %%
# best random forest so far
best_rf = load_pickle('trained_models\\rf_best.pkl')
best_rf
# Out:
# RandomForestRegressor(max_features=0.7297317866938179, max_samples=184,
#                       min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                       oob_score=True)

# %%
model_rmse(best_rf, valid_xs, valid_y)
# Out:
# 0.078015

# %% [markdown]
# Below are the hyperparameter tuning loops I used to find this best random forest but with which I cannot consistently replicate it.

# %%
# forests = {}

# for num in (5*x for x in range(1, 11)):
#     forest = rf(xs, y, min_samples_leaf=num) # minimum number of samples at which you can split the node
#     error = model_rmse(forest, valid_xs, valid_y)
#     forests[error] = forest

# from random import uniform
# for num in (uniform(0,1) for i in range(21)):
#     forest = rf(xs, y, max_features=num) # minimum number of samples at which you can split the node
#     error = model_rmse(forest, valid_xs, valid_y)
#     forests[error] = forest

# %%
#forests
# Out:
# {0.083741: RandomForestRegressor(max_features=0.5, max_samples=184, min_samples_leaf=5,
#                        n_estimators=40, n_jobs=-1, oob_score=True),
#  0.095285: RandomForestRegressor(max_features=0.5, max_samples=184, min_samples_leaf=10,
#                        n_estimators=40, n_jobs=-1, oob_score=True),
#  0.094422: RandomForestRegressor(max_features=0.5, max_samples=184, min_samples_leaf=15,
#                        n_estimators=40, n_jobs=-1, oob_score=True),
#  0.101337: RandomForestRegressor(max_features=0.5, max_samples=184, min_samples_leaf=20,
#                        n_estimators=40, n_jobs=-1, oob_score=True),
#  0.103987: RandomForestRegressor(max_features=0.5, max_samples=184, min_samples_leaf=25,
#                        n_estimators=40, n_jobs=-1, oob_score=True),
#  0.104949: RandomForestRegressor(max_features=0.5, max_samples=184, min_samples_leaf=30,
#                        n_estimators=40, n_jobs=-1, oob_score=True),
#  0.106319: RandomForestRegressor(max_features=0.5, max_samples=184, min_samples_leaf=35,
#                        n_estimators=40, n_jobs=-1, oob_score=True),
#  0.113132: RandomForestRegressor(max_features=0.5, max_samples=184, min_samples_leaf=40,
#                        n_estimators=40, n_jobs=-1, oob_score=True),
#  0.11387: RandomForestRegressor(max_features=0.5, max_samples=184, min_samples_leaf=45,
#                        n_estimators=40, n_jobs=-1, oob_score=True),
#  0.109848: RandomForestRegressor(max_features=0.5, max_samples=184, min_samples_leaf=50,
#                        n_estimators=40, n_jobs=-1, oob_score=True),
#  0.088802: RandomForestRegressor(max_features=0.8094304566778266, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.121: RandomForestRegressor(max_features=0.006498759678061017, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.082873: RandomForestRegressor(max_features=0.8058192518328079, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.086418: RandomForestRegressor(max_features=0.6981393949882269, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.091364: RandomForestRegressor(max_features=0.3402505165179919, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.117061: RandomForestRegressor(max_features=0.15547949981178155, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.08834: RandomForestRegressor(max_features=0.9572130722067812, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.102236: RandomForestRegressor(max_features=0.33659454511262676, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.109518: RandomForestRegressor(max_features=0.09274584338014791, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.112835: RandomForestRegressor(max_features=0.09671637683346401, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.085776: RandomForestRegressor(max_features=0.8474943663474598, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.086231: RandomForestRegressor(max_features=0.6037260313668911, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.089578: RandomForestRegressor(max_features=0.8071282732743802, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.078015: RandomForestRegressor(max_features=0.7297317866938179, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.089496: RandomForestRegressor(max_features=0.5362280914547007, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.084293: RandomForestRegressor(max_features=0.9731157639793706, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.094102: RandomForestRegressor(max_features=0.3785343772083535, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.07834: RandomForestRegressor(max_features=0.552040631273227, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.086975: RandomForestRegressor(max_features=0.8294046642529949, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.084321: RandomForestRegressor(max_features=0.6185197523642461, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True),
#  0.083041: RandomForestRegressor(max_features=0.8617069003107772, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True)}

# %%
# best = (min(forests), forests[min(forests)])
# best
# Out:
# (0.078015,
#  RandomForestRegressor(max_features=0.7297317866938179, max_samples=184,
#                        min_samples_leaf=5, n_estimators=40, n_jobs=-1,
#                        oob_score=True))

# %%
# for estimators in (5*x for x in range(1, 41)):
#     for samples in (5*x for x in range(1,36)):
#         forest = rf(xs, y, max_samples=samples, 
#                     n_estimators=estimators, 
#                     max_features=0.8, 
#                     min_samples_leaf=5) 
#         error = model_rmse(forest, valid_xs, valid_y)
#         forests[error] = forest
        
# forests

# %%
# best = (min(forests), forests[min(forests)])
# best

# %% [markdown]
# <font size=6> Neural Networks</font>

# %%
# Model with hyperparams chosen from some non-nested and thus non-exhaustive loops for tuning, not shown in this notebook,
# but that gives the best performance I've been able to achieve so far:

best_net = load_pickle('trained_models\\0.076_error_neural_net.pkl')

# %% [markdown]
# Even using the same hyperparams, due to the stochasticity inherent in neural network training I've been unable to get as low of an error as the model itself, so I will use best_net itself for future inference. It is placed manually in the same folder to which dtree_best and rf_best are saved using code.

# %% [markdown]
# What follows is the code used to train a neural net, though its performance will likely be worse than best_net.

# %%
df_nn = pd.read_csv('..\\prepared_data\\dataset_7-24.csv', low_memory=False)

cond = df_nn.year<=2010
import numpy as np
train_idx = np.where(cond)[0] # if condition only param passed, returns indices of dataframe where conditions true
valid_idx = np.where(~cond)[0] # why the [0] ?
splits = (list(train_idx),list(valid_idx))

# %%
df_nn.drop(columns=['year', 'Dem_candidate', 'Repub_candidate', 'state'],inplace=True)
cont_nn, cat_nn = cont_cat_split(df_nn, 50, dep_var='Repub%of_two-party_vote') # splits into cont or cat based on whether var has more than whatever the specified number (e.g., 50) of different values

# %%
procs_nn = [Categorify, FillMissing, Normalize]
to_nn = TabularPandas(df_nn, procs_nn, cat_nn, cont_nn,
                      splits=splits, y_names='Repub%of_two-party_vote')

# %%
dls0 = to_nn.dataloaders(32) # batch size 32, determined from prior experimentation to perform well
xs,y = to_nn.train.xs,to_nn.train.y
valid_xs,valid_y = to_nn.valid.xs,to_nn.valid.y

# %%
learn = tabular_learner(dls0, config={"act_cls": nn.ReLU()}, loss_func=F.mse_loss)

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0010000000474974513)

# %%
learn.fit(200, 0.001)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.301511</td>
#       <td>0.169348</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.261805</td>
#       <td>0.145809</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.227721</td>
#       <td>0.145866</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.204992</td>
#       <td>0.125714</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.185569</td>
#       <td>0.123988</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.166750</td>
#       <td>0.121173</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.150370</td>
#       <td>0.067040</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.137110</td>
#       <td>0.118574</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.125827</td>
#       <td>0.075993</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.114757</td>
#       <td>0.075884</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.104248</td>
#       <td>0.097700</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.094716</td>
#       <td>0.044661</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.085530</td>
#       <td>0.068040</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.077658</td>
#       <td>0.042480</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.070682</td>
#       <td>0.054329</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.063835</td>
#       <td>0.043432</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.058006</td>
#       <td>0.046124</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.052675</td>
#       <td>0.036972</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.048037</td>
#       <td>0.025749</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.043705</td>
#       <td>0.019438</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.039851</td>
#       <td>0.019198</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.036666</td>
#       <td>0.024933</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.033896</td>
#       <td>0.012544</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.031290</td>
#       <td>0.029652</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.029258</td>
#       <td>0.017279</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.027313</td>
#       <td>0.024714</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.025352</td>
#       <td>0.021103</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.023910</td>
#       <td>0.023458</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.022556</td>
#       <td>0.019595</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.020939</td>
#       <td>0.015877</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.019512</td>
#       <td>0.021634</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.018332</td>
#       <td>0.012459</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.017032</td>
#       <td>0.022905</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.016160</td>
#       <td>0.021983</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.015126</td>
#       <td>0.027524</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.014124</td>
#       <td>0.015349</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.013439</td>
#       <td>0.024279</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.012572</td>
#       <td>0.016608</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.011832</td>
#       <td>0.013028</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.011382</td>
#       <td>0.016716</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.010949</td>
#       <td>0.011334</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.010409</td>
#       <td>0.021184</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.009989</td>
#       <td>0.010776</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.009526</td>
#       <td>0.014310</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.009200</td>
#       <td>0.012257</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.008959</td>
#       <td>0.010732</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.009020</td>
#       <td>0.016468</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.008848</td>
#       <td>0.008987</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.008547</td>
#       <td>0.018634</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.008398</td>
#       <td>0.011049</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.008288</td>
#       <td>0.017143</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.008244</td>
#       <td>0.008464</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.008075</td>
#       <td>0.009992</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.007837</td>
#       <td>0.016816</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.007801</td>
#       <td>0.012622</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.007532</td>
#       <td>0.021254</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.007353</td>
#       <td>0.013041</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.007117</td>
#       <td>0.008548</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.006854</td>
#       <td>0.014135</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.006672</td>
#       <td>0.014326</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.006521</td>
#       <td>0.012041</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.006388</td>
#       <td>0.012895</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.006221</td>
#       <td>0.011805</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.006075</td>
#       <td>0.011849</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.005994</td>
#       <td>0.010137</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.005921</td>
#       <td>0.012305</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.005621</td>
#       <td>0.010534</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.005393</td>
#       <td>0.011633</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.005221</td>
#       <td>0.010230</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.005096</td>
#       <td>0.011076</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.005094</td>
#       <td>0.009084</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.005187</td>
#       <td>0.014376</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.005179</td>
#       <td>0.019355</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.005112</td>
#       <td>0.010

# %%
preds,targs = learn.get_preds()

# validation set error
r_mse(preds,targs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# 0.086524

# %%
preds,targs = best_net.get_preds()

# validation set error
r_mse(preds,targs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# 0.076316

# %% [markdown]
# Ideally, one would run an (at least moreso) exhaustive hyperparam tuning loop, as below.
# However, this is time intensive, and I am satisfied with the performance of best_net

# %%
# neural_nets = {}

# nums_of_layers = range(2,21)
# nodes_per_layer = [100*x for x in range(1,6)]
# learn_rates = (0.0001, 0.0005, 0.001, 0.005, 0.01)
# num_epochs = [10*x for x in range(1,31)]
# activ_funcs = (nn.ReLU(), nn.Sigmoid())
# batch_sizes = (1, 2, 4, 8, 16, 25, 32, 50, 75, 100, 125, 150, 184)

# for num_layers in nums_of_layers:
#     for num_nodes in nodes_per_layer:
#         for rate in learn_rates:
#             for epochs in num_epochs:
#                 for act in activ_funcs():
#                     for batch_size in batch_sizes:
#                         dls = to_nn.dataloaders(batch_size)
#                         learn = tabular_learner(dls, y_range=(0,1), layers=[num_nodes for layer in range(num_layers+1)], config={"act_cls": nn.ReLU()}, 
#                                         n_out=1, loss_func=F.mse_loss)
#                         learn.fit(epochs, rate)
#                         preds,targs = learn.get_preds()
#                         error = r_mse(preds, targs)
#                         neural_nets[error] = f'{num_layers} layers, {num_nodes} nodes, {rate} learning rate, {epochs} epochs, {act} activations'

# for i in range(10000):
#     num_layers = np.random.randint(low=2, high=21)
#     nodes_per_layer = np.random.randint(low=100, high=600)
#     learn_rates = 10**np.random.random(low=-4, high=-2)

# %% [markdown]
# <font size = 6 > Ensembling </font>

# %%
best_rf = load_pickle('trained_models\\rf_best.pkl')

# %%
model_rmse(best_rf, valid_xs, valid_y)
# Out:
# 0.078015

# %%
rf_preds = best_rf.predict(valid_xs)
ens_preds = (to_np(preds.squeeze()) + rf_preds) /2

# %%
r_mse(ens_preds,valid_y)
# Out:
# 0.073931

# %%
ens_preds
# Out:
# array([0.57039493, 0.35115744, 0.46563649, 0.35061289, 0.49551894, 0.3725004 , 0.51678465, 0.49046254, 0.32031004, 0.37513092, 0.44148069, 0.44079915, 0.59190679, 0.5353872 , 0.58017938, 0.5448891 ,
#        0.50807554, 0.39119375, 0.52777127, 0.39251783, 0.57140224, 0.5289039 , 0.47532975, 0.39124829, 0.60715787, 0.51170349, 0.66673642, 0.48853167, 0.42404578, 0.47937978, 0.50991822, 0.67442683])
